# %%
using Printf;

#Obilczanie rekurencyjne jednego współczynnika wielomianu
function coeff(a, b, i, n, k, w)
    if(a == n+1)
        if(b == 0)
            return w;
        else
            return Float64(0.0);
        end
    end
    if(a == k)
        return coeff(a+Float64(1.0), b, i, n, k, w);
    end
    wyn = coeff(a+1, b, i, n, k, w * Float64(-a));
    if(b > 0)
        wyn = wyn + coeff(a+1, b-1, i, n, k, w);
    end
    return wyn;
end

#Obliczanie całki
function integral(n, k)
    wyn = Float64(0.0);
    for i in 0:n
        N = Float64(1.0);
        for j in 1:(i+1)
            N = N * n;
        end
        N = N / (i+1);
        M = coeff(Float64(0.0), i, i, n, k, Float64(1.0));
        N = N * M;
        wyn = wyn + N;
    end
    return wyn;
end

function A_k(h, n, k)
    sign = Float64(1.0);
    for i in 1:(n-k)
        sign = sign * Float64(-1.0);
    end
    k1 = k2 = Float64(1.0);
    for i in 1:k
        k1 = k1 * Float64(i);
    end
    for i in 1:(n-k)
        k2 = k2 * Float64(i);
    end
    k1 = k1 * k2;
    h = (sign * h)/k1;
    I = integral(n,k);
    h = h * I;
    #@printf("%f : %f\n", k ,h);
    return h;
end

#Liczy sumy B_k
function suma(a, b, n)
    s = Float64(0.0);
    h = (b-a)/n;
    for i in 0:n
        B = A_k(h,n,i);
        B = B/(b-a);
        if(B < 0.0)
            @printf("Less than zero: n:%d i:%d B:%f\n", n, i, B);
        end
        B = abs(B);
        s = s+B;
    end
    @printf("Value for n = %d is: %f\n", n, s);
end

#Liczy kwadratury
function quadrature(f, n, a, b)
    h = (b-a)/n;
    q = 0.0;
    for k in 0:n
        A = A_k(h, n, k);
        x = f(a + k * h);
        q = q + A * x;
    end
    #println(q);
    return q;
end

# Zadanie 4
for i in 1:20
   suma(0, 1, i);
end
# Out:
# Value for n = 1 is: 1.000000
# Value for n = 2 is: 1.000000
# Value for n = 3 is: 1.000000
# Value for n = 4 is: 1.000000
# Value for n = 5 is: 1.000000
# Value for n = 6 is: 1.000000
# Value for n = 7 is: 1.000000
# Less than zero: n:8 i:2 B:-0.032734
# Less than zero: n:8 i:4 B:-0.160141
# Less than zero: n:8 i:6 B:-0.032734
# Value for n = 8 is: 1.451217
# Value for n = 9 is: 1.000000
# Less than zero: n:10 i:2 B:-0.081044
# Less than zero: n:10 i:4 B:-0.435155
# Less than zero: n:10 i:6 B:-0.435155
# Less than zero: n:10 i:8 B:-0.081044
# Value for n = 10 is: 3.064795
# Less than zero: n:11 i:2 B:-0.037169
# Less than zero: n:11 i:4 B:-0.110178
# Less than zero: n:11 i:7 B:-0.110178
# Less than zero: n:11 i:9 B:-0.037169
# Value for n = 11 is: 1.589389
# Less than zero: n:12 i:2 B:-0.120322
# Less than zero: n:12 i:4 B:-0.816506
# Less than zero: n:12 i:6 B:-1.392213
# Less than zero: n:12 i:8 B:-0.816506
# Less than zero: n:12 i:10 B:-0.120322
# Value for n = 12 is: 7.531737
# Less than zero: n:13 i:2 B:-0.077712
# Less than zero: n:13 i:4 B:-0.376924
# Less than zero: n:13 i:6 B:-0.107147
# Less than zero: n:13 i:7 B:-0.107147
# Less than zero: n:13 i:9 B:-0.376924
# Less than zero: n:13 i:11 B:-0.077712
# Value for n = 13 is: 3.247133
# Less than zero: n:14 i:2 B:-0.154025
# Less than zero: n:14 i:4 B:-1.323998
# Less than zero: n:14 i:6 B:-3.357864
# Less than zero: n:14 i:8 B:-3.357864
# Less than zero: n:14 i:10 B:-1.323998
# Less than zero: n:14 i:12 B:-0.154025
# Value for n = 14 is: 20.343550
# Less than zero: n:15 i:2 B:-0.112723
# Less than zero: n:15 i:4 B:-0.756293
# Less than zero: n:15 i:6 B:-0.968003
# Less than zero: n:15 i:9 B:-0.968005
# Less than zero: n:15 i:11 B:-0.756293
# Less than zero: n:15 i:13 B:-0.112723
# Value for n = 15 is: 8.348080
# Less than zero: n:16 i:2 B:-0.183977
# Less than zero: n:16 i:4 B:-1.975076
# Less than zero: n:16 i:6 B:-6.967291
# Less than zero: n:16 i:8 B:-10.475971
# Less than zero: n:16 i:10 B:-6.967306
# Less than zero: n:16 i:12 B:-1.975074
# Less than zero: n:16 i:14 B:-0.183976
# Value for n = 16 is: 58.457347
# Less than zero: n:17 i:2 B:-0.143921
# Less than zero: n:17 i:4 B:-1.266284
# Less than zero: n:17 i:6 B:-2.895688
# Less than zero: n:17 i:8 B:-0.998237
# Less than zero: n:17 i:9 B:-0.998292
# Less than zero: n:17 i:11 B:-2.895691
# Less than zero: n:17 i:13 B:-1.266275
# Less than zero: n:17 i:15 B:-0.143922
# Value for n = 17 is: 22.216652
# Less than zero: n:18 i:2 B:-0.211237
# Less than zero: n:18 i:4 B:-2.785702
# Less than zero: n:18 i:6 B:-13.061077
# Less than zero: n:18 i:8 B:-27.556925
# Less than zero: n:18 i:10 B:-27.557485
# Less than zero: n:18 i:12 B:-13.061033
# Less than zero: n:18 i:14 B:-2.785730
# Less than zero: n:18 i:16 B:-0.211237
# Value for n = 18 is: 175.461600
# Less than zero: n:19 i:2 B:-0.172353
# Less than zero: n:19 i:4 B:-1.923539
# Less than zero: n:19 i:6 B:-6.570369
# Less than zero: n:19 i:8 B:-6.897429
# Less than zero: n:19 i:11 B:-6.895024
# Less than zero: n:19 i:13 B:-6.568497
# Less than zero: n:19 i:15 B:-1.923128
# Less than zero: n:19 i:17 B:-0.172334
# Value for n = 19 is: 63.254622
# Less than zero: n:20 i:2 B:-0.236527
# Less than zero: n:20 i:4 B:-3.769837
# Less than zero: n:20 i:6 B:-22.701281
# Less than zero: n:20 i:8 B:-64.065456
# Less than zero: n:20 i:10 B:-89.981923
# Less than zero: n:20 i:12 B:-64.068303
# Less than zero: n:20 i:14 B:-22.710040
# Less than zero: n:20 i:16 B:-3.771479
# Less than zero: n:20 i:18 B:-0.236476
# Value for n = 20 is: 544.079276

# %%
#zadanie 5
function foo(x)
    wyn = x*x + 1.0;
    wyn = 1 / wyn;
    return wyn;
end

@printf("Exact value is: %f\n", 2 * atan(4));
for i in 1:5
   q = quadrature(foo, 2*i, -4, 4);
   @printf("Value of quadrature for n = %d is: %f\n", 2*i, q);
end
# Out:
# Exact value is: 2.651635
# Value of quadrature for n = 2 is: 5.490196
# Value of quadrature for n = 4 is: 2.277647
# Value of quadrature for n = 6 is: 3.328798
# Value of quadrature for n = 8 is: 1.941094
# Value of quadrature for n = 10 is: 3.595560
